# %%
from Agent.configs.AI import *

# %%
from Agent.configs.Agents.TypesAg import *

# %%
from swarm.repl import run_demo_loop

# %%
from datetime import datetime

# %%
if __name__ == "__main__":
    run_demo_loop(triage_agent, debug=False, stream=True)
# Out:
# Starting Swarm CLI 🐝
# User:  hola quiero hacer un viaje a Huajuapan
# Main Agent: Puedo ayudarte a hacer una reservación para tu viaje a Huajuapan. Permíteme transferir tu solicitud a la sección correspondiente para procesar tu reservación.: switch_main_ag()
#
# Principal Agent: Ya estás en la sección principal de reservas. ¿Te gustaría información sobre hoteles, restaurantes, atracciones, transporte o renta de autos en Huajuapan?
# User:  quiero información de hoteles, restaurantes y tours
# Principal Agent: consultar_hoteles()
# Principal Agent: consultar_restaurantes()
# Principal Agent: consultar_atracciones()
# Principal Agent: Aquí tienes la información que solicitas para tu viaje a Huajuapan:
#
# **Hoteles disponibles:**
# 1. **Hotel del Portal**
#    - Dirección: Calle Valerio Trujano 5, Centro, Huajuapan de León
#    - Categoría: 3 estrellas
#    - Servicios: WiFi, restaurante, estacionamiento, recepción 24 horas, cerca del Zócalo.
#
# 2. **Hotel La Cabaña**
#    - Dirección: Carretera Internacional Km 2, Huajuapan de León
#    - Categoría: 4 estrellas
#    - Servicios: Piscina, restaurante, jardín, estacionamiento, habitaciones familiares.
#
# 3. **Hotel San Miguel**
#    - Dirección: Calle Morelos 18, Centro Histórico, Huajuapan de León
#    - Categoría: 3 estrellas
#    - Servicios: WiFi, terraza, servicio de habitaciones, desayuno incluido, atención personalizada.
#
# **Restaurantes recomendados:**
# 1. **Comedor Lupita**
#    - Ubicación: Calle Morelos 45, Centro, Huajuapan de León
#    - Especialidad: Comida mixteca tradicional
#    - Descripción: Ofrece tamales de chileajo, mole mixteco y atención casera en ambiente familiar.
#
# 2. **Restaurante El Campanario**
#    - Ubicación: Av. 5 de Febrero 102, Huajuapan de León
#    - Especialidad: Mexicana y regional
#    - Descripción: Restaurante amplio con menú variado, ideal para grupos y celebraciones locales.
#
# 3. **Café La Cosecha**
#    - Ubicación: Calle Valerio Trujano 12, Centro, Huajuapan de León
#    - Especialidad: Café y repostería artesanal
#    - Descripción: Perfecto para desayunos, café local y postres caseros en un ambiente tranquilo.
#
# **Atracciones y tours:**
# 1. **Museo Regional de Huajuapan**
#    - Tipo: Cultural
#    - Descripción: Colección arqueológica y etnográfica de la Mixteca Alta.
#
# 2. **Templo de San Juan Bautista**
#    - Tipo: Histórica
#    - Descripción: Iglesia colonial con arquitectura barroca y valor histórico.
#
# 3. **Mirador del Cerro de las Minas**
#    - Tipo: Escénica
#    - Descripción: Vista panorámica de la ciudad y zona arqueológica mixteca.
#
# Espero que esta información sea útil para tu viaje. Si necesitas reservar alguno de estos servicios, por favor házmelo saber.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 if __name__ == "__main__":
# ----> 2     run_demo_loop(triage_agent, debug=False, stream=True)
#
# File ~\miniconda3\envs\Prueba\Lib\site-packages\swarm\repl\repl.py:70, in run_demo_loop(starting_agent, context_variables, stream, debug)
#      67 agent = starting_agent
#      69 while True:
# ---> 70     user_input = input("\033User\033: ")
#      71     messages.append({"role": "user", "content": user_input})
#      73     response = client.run(
#      74         agent=agent,
#      75         messages=messages,
#    (...)     78         debug=debug,
#      79     )
#
# File ~\miniconda3\envs\Prueba\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\Prueba\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
