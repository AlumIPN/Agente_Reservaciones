# %%
from swarm import Agent

# %%
from Agent2.configs.prompts import *

# %%
from Agent2.configs.Data.context_variables import *

# %%
from Agent2.configs.tools.switchers import *
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from Agent2.configs.tools.switchers import *
#
# File ~\miniconda3\envs\Prueba\Agent2\configs\tools\switchers.py:1
# ----> 1 from Agent2.configs.agents.types import *
#       3 def switch_to_availability_agent():
#       4     from configs.agents.types import availability_agent
#
# File ~\miniconda3\envs\Prueba\Agent2\configs\agents\types.py:8
#       3 from Agent2.configs.Data.context_variables import *
#       4 from Agent2.configs.tools.switchers import *
#       6 availability_agent = Agent(
#       7     name="Availability Agent",
# ----> 8     instructions=availability_instructions(context_variables),
#       9     functions=[
#      10     ]
#      11 )
#      13 cancellation_agent = Agent(
#      14     name="Cancellation Agent",
#      15     instructions=cancellation_instructions(context_variables),
#      16     functions=[get_rag_response]
#      17 )
#      19 reviews_agent = Agent(
#      20     name="Reviews Agent",
#      21     instructions=reviews_instructions(context_variables),
#      22     functions=[]
#      23 )
#
# NameError: name 'availability_instructions' is not defined

# %%
availability_agent = Agent(
    name="Availability Agent",
    instructions=availability_instructions(context_variables),
    functions=[
    ]
)

# %%
triage_agent = Agent(
    name="Triage Agent",
    instructions=triage_instructions(context_variables),
    functions=[
        switch_to_availability_agent,
        switch_to_cancellation_agent,
        switch_to_reviews_agent,
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       1 triage_agent = Agent(
#       2     name="Triage Agent",
#       3     instructions=triage_instructions(context_variables),
#       4     functions=[
# ----> 5         switch_to_availability_agent,
#       6         switch_to_cancellation_agent,
#       7         switch_to_reviews_agent,
#       8     ]
#       9 )
#
# NameError: name 'switch_to_availability_agent' is not defined

# %%
triage_agent = Agent(
    name="Triage Agent",
    instructions= a
    functions=[
        switch_to_availability_agent,
        switch_to_cancellation_agent,
        switch_to_reviews_agent,
    ]
)
