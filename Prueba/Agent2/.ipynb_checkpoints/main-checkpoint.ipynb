# %%
from Agent2.configs.agents.types import *

# %%
from swarm.repl import run_demo_loop

# %%
from datetime import datetime

# %%
if __name__== "__main__":
    run_demo_loop(triage_agent, debug=False, stream=True)
# Out:
# Starting Swarm CLI 🐝
# User:  hola
# Triage Agent: ¡Hola Brandon! ¿En qué puedo ayudarte hoy?
# User:  quiero hacer una cancelacion
# Triage Agent: ¿Podrías decirme qué tour o reserva te gustaría cancelar, Brandon?
# User:  perdon, quiero hacer un tour por Mexico
# Triage Agent: switch_to_availability_agent()
# Availability Agent: Lo siento, no tengo información sobre tours en México en este momento. ¿Hay algo más en lo que te pueda ayudar?
# User:  quiero hacer un cambio
# Availability Agent: switch_to_cancellation_agent()
# Cancellation Agent: Claro, Brandon. ¿Qué cambio necesitas realizar en tu reserva?
# User:  cambiar de hotel
# Cancellation Agent: Disculpa, no tengo la capacidad de realizar cambios relacionados con hoteles. Te recomendaría contactar directamente al servicio de atención al cliente del hotel o al proveedor con quien realizaste la reserva para gestionar el cambio. ¿Hay algo más en lo que pueda ayudarte?

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"
